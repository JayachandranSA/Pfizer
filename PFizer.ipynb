# %%
#Installing Prerequisites
# !pip install --upgrade gdown
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.1.0
#     Uninstalling gdown-5.1.0:
#       Successfully uninstalled gdown-5.1.0
# ...

# %%
import numpy as np, pandas as pd

# %%
# !gdown 173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 4.18MB/s]

# %%
pdf=pd.read_csv('Pfizer_1.csv')
pdf.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
pdf.shape
# Out:
# (18, 15)

# %%
pdf.columns
# Out:
# Index(['Date', 'Drug_Name', 'Parameter', '1:30:00', '2:30:00', '3:30:00',
#        '4:30:00', '5:30:00', '6:30:00', '7:30:00', '8:30:00', '9:30:00',
#        '10:30:00', '11:30:00', '12:30:00'],
#       dtype='object')

# %%
#Melting

# %%
pdf.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
pdf.columns
# Out:
# Index(['Date', 'Drug_Name', 'Parameter', '1:30:00', '2:30:00', '3:30:00',
#        '4:30:00', '5:30:00', '6:30:00', '7:30:00', '8:30:00', '9:30:00',
#        '10:30:00', '11:30:00', '12:30:00'],
#       dtype='object')

# %%
pdf_melt=pd.melt(pdf,id_vars=['Date', 'Drug_Name', 'Parameter'],var_name='Time',value_name='Readings')
pdf_melt
# Out:
#            Date                Drug_Name    Parameter      Time  Readings
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00      23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00      12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00       NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00       NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00      24.0
# ..          ...                      ...          ...       ...       ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00      14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00      23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00      28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00      24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00      15.0
#
# [216 rows x 5 columns]

# %%
#Pivot

# %%
pdf_melt.pivot(index=['Date', 'Drug_Name', 'Parameter'],columns='Time',values='Readings').reset_index()
# Out:
# Time        Date                Drug_Name    Parameter  10:30:00  11:30:00  \
# 0     15-10-2020  diltiazem hydrochloride     Pressure      18.0      19.0
# 1     15-10-2020  diltiazem hydrochloride  Temperature      20.0      20.0
# 2     15-10-2020      docetaxel injection     Pressure      26.0      29.0
# 3     15-10-2020      docetaxel injection  Temperature      23.0      25.0
# 4     15-10-2020   ketamine hydrochloride     Pressure       9.0       9.0
# 5     15-10-2020   ketamine hydrochloride  Temperature      22.0      21.0
# 6     16-10-2020  diltiazem hydrochloride     Pressure      24.0       NaN
# 7     16-10-2020  diltiazem hydrochloride  Temperature      40.0       NaN
# 8     16-10-2020      docetaxel injection     Pressure      28.0      29.0
# 9     16-10-2020      docetaxel injection  Temperature      56.0      57.0
# 10    16-10-2020   ketamine hydrochloride     Pressure      16.0      17.0
# ...

# %%
pdf_melt.head()
# Out:
#          Date                Drug_Name    Parameter     Time  Readings
# 0  15-10-2020  diltiazem hydrochloride  Temperature  1:30:00      23.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure  1:30:00      12.0
# 2  15-10-2020      docetaxel injection  Temperature  1:30:00       NaN
# 3  15-10-2020      docetaxel injection     Pressure  1:30:00       NaN
# 4  15-10-2020   ketamine hydrochloride  Temperature  1:30:00      24.0

# %%
#Converting Parameter Temperature and pressure from rows into two columns

# %%
pdf_pivot=pdf_melt.pivot(index=['Date','Time','Drug_Name'],
               columns='Parameter',
               values='Readings').reset_index()
pdf_pivot
# Out:
# Parameter        Date      Time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# ..                ...       ...                      ...       ...
# 103        17-10-2020   8:30:00      docetaxel injection      26.0
# 104        17-10-2020   8:30:00   ketamine hydrochloride      11.0
# 105        17-10-2020   9:30:00  diltiazem hydrochloride       9.0
# 106        17-10-2020   9:30:00      docetaxel injection      27.0
# 107        17-10-2020   9:30:00   ketamine hydrochloride      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 23.0
# 2                 22.0
# 3                 20.0
# 4                 25.0
# ...

# %%
pdf_pivot.columns.name=None
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [108 rows x 5 columns]

# %%
pdf_melt
# Out:
#            Date                Drug_Name    Parameter      Time  Readings
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00      23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00      12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00       NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00       NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00      24.0
# ..          ...                      ...          ...       ...       ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00      14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00      23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00      28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00      24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00      15.0
#
# [216 rows x 5 columns]

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [108 rows x 5 columns]

# %%
pdf_pivot.head()
# Out:
#          Date      Time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %%
pdf_temp=pd.pivot_table(pdf_pivot,index=['Drug_Name'],columns='Date',values='Temperature',aggfunc=np.mean).reset_index()
pdf_temp
# Out:
# <ipython-input-22-788c25868db1>:1: FutureWarning: The provided callable <function mean at 0x7f1557b17d90> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pdf_temp=pd.pivot_table(pdf_pivot,index=['Drug_Name'],columns='Date',values='Temperature',aggfunc=np.mean).reset_index()
# Date                Drug_Name  15-10-2020  16-10-2020  17-10-2020
# 0     diltiazem hydrochloride   21.454545   37.454545   15.636364
# 1         docetaxel injection   20.750000   51.454545   17.500000
# 2      ketamine hydrochloride   23.555556   11.500000   18.500000

# %%
pdf_temp.columns.name=None
pdf_temp
# Out:
#                  Drug_Name  15-10-2020  16-10-2020  17-10-2020
# 0  diltiazem hydrochloride   21.454545   37.454545   15.636364
# 1      docetaxel injection   20.750000   51.454545   17.500000
# 2   ketamine hydrochloride   23.555556   11.500000   18.500000

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [108 rows x 5 columns]

# %%
pdf_pivot.groupby(['Drug_Name','Date'])['Temperature'].aggregate(['mean']).reset_index()
# Out:
#                  Drug_Name        Date       mean
# 0  diltiazem hydrochloride  15-10-2020  21.454545
# 1  diltiazem hydrochloride  16-10-2020  37.454545
# 2  diltiazem hydrochloride  17-10-2020  15.636364
# 3      docetaxel injection  15-10-2020  20.750000
# 4      docetaxel injection  16-10-2020  51.454545
# 5      docetaxel injection  17-10-2020  17.500000
# 6   ketamine hydrochloride  15-10-2020  23.555556
# 7   ketamine hydrochloride  16-10-2020  11.500000
# 8   ketamine hydrochloride  17-10-2020  18.500000

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [108 rows x 5 columns]

# %%
pd.pivot_table(pdf_pivot,index=['Drug_Name'],columns='Date',values=['Pressure','Temperature'],aggfunc=np.min).reset_index()
# Out:
# <ipython-input-27-0a4d3ab020f8>:1: FutureWarning: The provided callable <function min at 0x7f1557b175b0> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   pd.pivot_table(pdf_pivot,index=['Drug_Name'],columns='Date',values=['Pressure','Temperature'],aggfunc=np.min).reset_index()
#                     Drug_Name   Pressure                       Temperature  \
# Date                          15-10-2020 16-10-2020 17-10-2020  15-10-2020
# 0     diltiazem hydrochloride       11.0       18.0        3.0        20.0
# 1         docetaxel injection       22.0       23.0       20.0        17.0
# 2      ketamine hydrochloride        7.0       12.0        8.0        20.0
#
#
# Date 16-10-2020 17-10-2020
# 0          34.0       10.0
# 1          46.0       12.0
# 2           8.0       13.0

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [108 rows x 5 columns]

# %%
#Binning
pdf_pivot['Temperature'].min() ,pdf_pivot['Temperature'].max()
# Out:
# (8.0, 58.0)

# %%
temp_bins=[5,20,35,50,60]
temp_labels=['Low','medium','high','very_high']

# %%
pdf_pivot['Temp_category']=pd.cut(pdf_pivot['Temperature'],bins=temp_bins,labels=temp_labels)
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     Temp_category
# 0             Low
# 1          medium
# 2          medium
# ...

# %%
pdf_pivot['Temp_category'].value_counts()
# Out:
# Temp_category
# Low          45
# medium       30
# high         15
# very_high     5
# Name: count, dtype: int64

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     Temp_category
# 0             Low
# 1          medium
# 2          medium
# ...

# %%
pdf.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
pdf.isna().head()
# Out:
#     Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0  False      False      False    False    False     True    False    False
# 1  False      False      False    False    False     True    False    False
# 2  False      False      False     True    False    False     True    False
# 3  False      False      False     True    False    False     True    False
# 4  False      False      False    False     True     True    False     True
#
#    6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  11:30:00  12:30:00
# 0    False    False    False    False     False     False     False
# 1    False    False    False    False     False     False     False
# 2    False     True     True    False     False     False     False
# 3    False     True     True    False     False     False     False
# 4    False    False    False    False     False     False     False

# %%
pd.Series(['1',np.nan])
# Out:
# 0      1
# 1    NaN
# dtype: object

# %%
pdf.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
pdf.isnull().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
pdf.isna().sum(axis=1)
# Out:
# 0     1
# 1     1
# 2     4
# 3     4
# 4     3
# 5     3
# 6     1
# 7     1
# 8     1
# 9     1
# 10    2
# 11    2
# 12    1
# 13    1
# 14    0
# 15    0
# 16    0
# 17    0
# dtype: int64

# %%
pdf.fillna(5)
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      5.0     17.0
# 3   15-10-2020      docetaxel injection     Pressure      5.0     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      5.0
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      5.0
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pdf.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
pdf.dropna()
# Out:
#           Date               Drug_Name    Parameter  1:30:00  2:30:00  \
# 14  17-10-2020     docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020     docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020  ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020  ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
pdf
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pdf['3:30:00']
# Out:
# 0      NaN
# 1      NaN
# 2     18.0
# 3     22.0
# 4      NaN
# 5      NaN
# 6     36.0
# 7     20.0
# 8      NaN
# 9      NaN
# 10    10.0
# 11    13.0
# 12    19.0
# 13     4.0
# 14    14.0
# 15    22.0
# 16    15.0
# 17    10.0
# Name: 3:30:00, dtype: float64

# %%
pdf['3:30:00'].isna().sum()
# Out:
# 6

# %%
pdf['3:30:00'].fillna(round(pdf['3:30:00'].mean()))
# Out:
# 0     17.0
# 1     17.0
# 2     18.0
# 3     22.0
# 4     17.0
# 5     17.0
# 6     36.0
# 7     20.0
# 8     17.0
# 9     17.0
# 10    10.0
# 11    13.0
# 12    19.0
# 13     4.0
# 14    14.0
# 15    22.0
# 16    15.0
# 17    10.0
# Name: 3:30:00, dtype: float64

# %%
pdf['3:30:00'].shape
# Out:
# (18,)

# %%
pdf['3:30:00'].count()
# Out:
# 12

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     Temp_category
# 0             Low
# 1          medium
# 2          medium
# ...

# %%
pdf_pivot['Temperature'].isna().sum()
# Out:
# 13

# %%
pdf_pivot.groupby("Drug_Name")[['Temperature','Pressure']].aggregate({'Temperature':['mean'],'Pressure':['mean']})
# Out:
#                         Temperature   Pressure
#                                mean       mean
# Drug_Name
# diltiazem hydrochloride   24.848485  15.424242
# docetaxel injection       30.387097  25.483871
# ketamine hydrochloride    17.709677  11.935484

# %%
pdf
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pdf.columns
# Out:
# Index(['Date', 'Drug_Name', 'Parameter', '1:30:00', '2:30:00', '3:30:00',
#        '4:30:00', '5:30:00', '6:30:00', '7:30:00', '8:30:00', '9:30:00',
#        '10:30:00', '11:30:00', '12:30:00'],
#       dtype='object')

# %%
pd.melt(pdf,id_vars=['Date', 'Drug_Name', 'Parameter'],var_name='time',value_name='readings')
# Out:
#            Date                Drug_Name    Parameter      time  readings
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00      23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00      12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00       NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00       NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00      24.0
# ..          ...                      ...          ...       ...       ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00      14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00      23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00      28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00      24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00      15.0
#
# [216 rows x 5 columns]

# %%
pdf_melt
# Out:
#            Date                Drug_Name    Parameter      Time  Readings
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00      23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00      12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00       NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00       NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00      24.0
# ..          ...                      ...          ...       ...       ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00      14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00      23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00      28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00      24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00      15.0
#
# [216 rows x 5 columns]

# %%
pdf_melt.columns
# Out:
# Index(['Date', 'Drug_Name', 'Parameter', 'Time', 'Readings'], dtype='object')

# %%
pdf_melt.pivot(index=['Date', 'Drug_Name', 'Time'],columns='Parameter',values='Readings').reset_index()
# Out:
# Parameter        Date                Drug_Name      Time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     Temp_category
# 0             Low
# 1          medium
# 2          medium
# ...

# %%
pdf_pivot.isna()
# Out:
#       Date   Time  Drug_Name  Pressure  Temperature  Temp_category
# 0    False  False      False     False        False          False
# 1    False  False      False     False        False          False
# 2    False  False      False     False        False          False
# 3    False  False      False     False        False          False
# 4    False  False      False     False        False          False
# ..     ...    ...        ...       ...          ...            ...
# 103  False  False      False     False        False          False
# 104  False  False      False     False        False          False
# 105  False  False      False     False        False          False
# 106  False  False      False     False        False          False
# 107  False  False      False     False        False          False
#
# [108 rows x 6 columns]

# %%
pdf_melt.isna()
# Out:
#       Date  Drug_Name  Parameter   Time  Readings
# 0    False      False      False  False     False
# 1    False      False      False  False     False
# 2    False      False      False  False      True
# 3    False      False      False  False      True
# 4    False      False      False  False     False
# ..     ...        ...        ...    ...       ...
# 211  False      False      False  False     False
# 212  False      False      False  False     False
# 213  False      False      False  False     False
# 214  False      False      False  False     False
# 215  False      False      False  False     False
#
# [216 rows x 5 columns]

# %%
pdf.isnull()
# Out:
#      Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0   False      False      False    False    False     True    False    False
# 1   False      False      False    False    False     True    False    False
# 2   False      False      False     True    False    False     True    False
# 3   False      False      False     True    False    False     True    False
# 4   False      False      False    False     True     True    False     True
# 5   False      False      False    False     True     True    False     True
# 6   False      False      False    False    False    False    False    False
# 7   False      False      False    False    False    False    False    False
# 8   False      False      False    False    False     True    False    False
# 9   False      False      False    False    False     True    False    False
# 10  False      False      False    False    False    False     True    False
# ...

# %%
pdf.isna()
# Out:
#      Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0   False      False      False    False    False     True    False    False
# 1   False      False      False    False    False     True    False    False
# 2   False      False      False     True    False    False     True    False
# 3   False      False      False     True    False    False     True    False
# 4   False      False      False    False     True     True    False     True
# 5   False      False      False    False     True     True    False     True
# 6   False      False      False    False    False    False    False    False
# 7   False      False      False    False    False    False    False    False
# 8   False      False      False    False    False     True    False    False
# 9   False      False      False    False    False     True    False    False
# 10  False      False      False    False    False    False     True    False
# ...

# %%
pdf['1:30:00']
# Out:
# 0     23.0
# 1     12.0
# 2      NaN
# 3      NaN
# 4     24.0
# 5      8.0
# 6     34.0
# 7     18.0
# 8     46.0
# 9     23.0
# 10     8.0
# 11    12.0
# 12    20.0
# 13     3.0
# 14    12.0
# 15    20.0
# 16    13.0
# 17     8.0
# Name: 1:30:00, dtype: float64

# %%
pdf['1:30:00'].isna()
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# Name: 1:30:00, dtype: bool

# %%
pdf['1:30:00'].isna().sum()
# Out:
# 2

# %%
pdf['1:30:00'].isna().count()
# Out:
# 18

# %%
pdf['1:30:00'].isna().shape
# Out:
# (18,)

# %%
pdf['1:30:00'].shape
# Out:
# (18,)

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     Temp_category
# 0             Low
# 1          medium
# 2          medium
# ...

# %%
pdf_pivot[pdf_pivot['Drug_Name'].str.contains('hydrochloride')]
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 5    15-10-2020  11:30:00   ketamine hydrochloride       9.0         21.0
# 6    15-10-2020  12:30:00  diltiazem hydrochloride      20.0         21.0
# ..          ...       ...                      ...       ...          ...
# 101  17-10-2020   7:30:00   ketamine hydrochloride      12.0         19.0
# 102  17-10-2020   8:30:00  diltiazem hydrochloride       NaN          NaN
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     Temp_category
# 0             Low
# 2          medium
# 3             Low
# ...

# %%
pdf_pivot['Date']
# Out:
# 0      15-10-2020
# 1      15-10-2020
# 2      15-10-2020
# 3      15-10-2020
# 4      15-10-2020
#           ...
# 103    17-10-2020
# 104    17-10-2020
# 105    17-10-2020
# 106    17-10-2020
# 107    17-10-2020
# Name: Date, Length: 108, dtype: object

# %%
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     Temp_category
# 0             Low
# 1          medium
# 2          medium
# ...

# %%
pdf_pivot['TimeStamp']=pdf_pivot["Date"]+' '+pdf_pivot['Time']
pdf_pivot
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     Temp_category            TimeStamp
# 0             Low  15-10-2020 10:30:00
# ...

# %%
pdf_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           108 non-null    object
#  1   Time           108 non-null    object
#  2   Drug_Name      108 non-null    object
#  3   Pressure       95 non-null     float64
#  4   Temperature    95 non-null     float64
#  5   Temp_category  95 non-null     category
#  6   TimeStamp      108 non-null    object
# dtypes: category(1), float64(2), object(4)
# memory usage: 5.5+ KB

# %%
#The TimeStamp is in Object datatype
#we need to convert it into  Date Time Data type

# %%
pdf_pivot['TimeStamp']=pd.to_datetime(pdf_pivot['TimeStamp'])
pdf_pivot
# Out:
# <ipython-input-76-3bf80ad0ad0b>:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pdf_pivot['TimeStamp']=pd.to_datetime(pdf_pivot['TimeStamp'])
#            Date      Time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# ...

# %%
pdf_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           108 non-null    object
#  1   Time           108 non-null    object
#  2   Drug_Name      108 non-null    object
#  3   Pressure       95 non-null     float64
#  4   Temperature    95 non-null     float64
#  5   Temp_category  95 non-null     category
#  6   TimeStamp      108 non-null    datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(2), object(3)
# memory usage: 5.5+ KB

# %%
ts=pdf_pivot['TimeStamp'][0]

# %%
ts
# Out:
# Timestamp('2020-10-15 10:30:00')

# %%
ts.year
# Out:
# 2020

# %%
ts.day_name()
# Out:
# 'Thursday'

# %%
ts.month
# Out:
# 10

# %%
ts.month_name
# Out:
# <function Timestamp.month_name>

# %%
pdf_pivot["TimeStamp"]
# Out:
# 0     2020-10-15 10:30:00
# 1     2020-10-15 10:30:00
# 2     2020-10-15 10:30:00
# 3     2020-10-15 11:30:00
# 4     2020-10-15 11:30:00
#               ...
# 103   2020-10-17 08:30:00
# 104   2020-10-17 08:30:00
# 105   2020-10-17 09:30:00
# 106   2020-10-17 09:30:00
# 107   2020-10-17 09:30:00
# Name: TimeStamp, Length: 108, dtype: datetime64[ns]

# %%
pdf_pivot["TimeStamp"].dt.time
# Out:
# 0      10:30:00
# 1      10:30:00
# 2      10:30:00
# 3      11:30:00
# 4      11:30:00
#          ...
# 103    08:30:00
# 104    08:30:00
# 105    09:30:00
# 106    09:30:00
# 107    09:30:00
# Name: TimeStamp, Length: 108, dtype: object

# %%
pdf_pivot['TimeStamp'][0]
# Out:
# Timestamp('2020-10-15 10:30:00')

# %%
#String format Time(strftime)

# %%
pdf_pivot['TimeStamp'][0].strftime('%B')
# Out:
# 'October'

# %%
pdf
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pdf[pdf.isna().any(axis=1)]
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pdf[pdf.isna().any(axis=1)].shape
# Out:
# (14, 15)

# %%
pdf.shape
# Out:
# (18, 15)

# %%
pdf['1:30:00'].isna().sum()
# Out:
# 2

# %%
pdf.isna().sum().sum()
# Out:
# 26

# %%
pdf.iloc[[3]]
# Out:
#          Date            Drug_Name Parameter  1:30:00  2:30:00  3:30:00  \
# 3  15-10-2020  docetaxel injection  Pressure      NaN     22.0     22.0
#
#    4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  11:30:00  \
# 3      NaN     22.0       23      NaN      NaN     27.0        26      29.0
#
#    12:30:00
# 3        28

# %%
pdf.iloc[[3]].isna().sum().sum()
# Out:
# 4

# %%
pdf_pivot.head()
# Out:
#          Date      Time                Drug_Name  Pressure  Temperature  \
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0
#
#   Temp_category           TimeStamp
# 0           Low 2020-10-15 10:30:00
# 1        medium 2020-10-15 10:30:00
# 2        medium 2020-10-15 10:30:00
# 3           Low 2020-10-15 11:30:00
# 4        medium 2020-10-15 11:30:00

# %%
pdf_pivot.groupby(["Date",'Drug_Name'])['Temperature'].mean()
# Out:
# Date        Drug_Name
# 15-10-2020  diltiazem hydrochloride    21.454545
#             docetaxel injection        20.750000
#             ketamine hydrochloride     23.555556
# 16-10-2020  diltiazem hydrochloride    37.454545
#             docetaxel injection        51.454545
#             ketamine hydrochloride     11.500000
# 17-10-2020  diltiazem hydrochloride    15.636364
#             docetaxel injection        17.500000
#             ketamine hydrochloride     18.500000
# Name: Temperature, dtype: float64
